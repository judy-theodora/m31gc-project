# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pickle
import astropy.coordinates as coord
import astropy.units as u
from astropy.io import ascii

# %%
CAT = pickle.load(open(f'pickle/cat101_150.pk','rb'))

# %%
CAT[133]
# Out:
# <Table length=200241>
#          RA                 Dec          iccd    xg   ...   ii    ia  field
#       float64             float64       int32 float64 ... int32 int32 int32
# -------------------- ------------------ ----- ------- ... ----- ----- -----
#   1.0128374999999998  36.43767222222222     1  785.91 ...    -9     0   133
#   1.0487499999999983  36.37831944444444     1 1342.38 ...    -9     0   133
#   1.0951958333333316          36.392575     1  2078.4 ...    -9     0   133
#   1.0806125000000009  36.43597777777777     1  1855.4 ...    -9     0   133
#   0.9879291666666674          36.357625     1  380.91 ...    -9     0   133
#   1.0602208333333323          36.412575     1 1529.03 ...    -9     0   133
#   0.9690666666666665  36.40425833333333     1   91.28 ...     0     0   133
#             1.065175  36.38341388888889     1 1602.47 ...    -9     0   133
#   1.0423583333333326  36.25856944444445     1 1225.57 ...    -9     0   133
#   1.0301125000000013  36.24165277777778     1  1030.7 ...    -9     0   133
#                  ...                ...   ...     ... ...   ...   ...   ...
# -0.10927916666668125 35.497708333333335    36 2160.94 ...    -1     0   133
# -0.10725833333333412  35.49384444444445    36 2129.75 ...     1     0   133
# -0.10836666666671135  35.49328888888889    36 2148.36 ...     1     0   133
#   -0.108949999999993 35.489358333333335    36 2158.78 ...     1     0   133
# -0.10777916666665988  35.48838611111111    36 2140.81 ...     1     0   133
# -0.10869166666674346  35.48903611111111    36 2155.41 ...     1     0   133
# -0.10826666666667961  35.48807777777778    36 2149.25 ...     1     0   133
#  -0.0853208333333555  35.46485277777778    36 1791.01 ...     0     0   133
# -0.08775833333334049  35.46485555555556    36 1829.96 ...     0     0   133
# -0.09944583333339096  35.46485555555556    36 2017.32 ...     0     0   133

# %%
master_cat = pd.read_csv('./catdata/master_catalog_jan_2023.csv') #2184 objects long

# %%
master_cat.head()
# Out:
#           ID     RADEG     DECDEG  CLASS                 DATATABLE
# 0         C1  0.157917  32.417778    2.0  di_tullio_zinn_13_table2
# 1      2M034  0.508375  51.606722    4.0                  m31rbcV5
# 2  PAndAS-03  0.985042  40.888667    1.0            huxor14_table1
# 3  PAndAS-04  1.178875  47.361797    1.0            huxor14_table1
# 4  PAndAS-05  1.350625  43.926583    1.0            huxor14_table1

# %%
gcs = master_cat[master_cat['CLASS'] == 1]

# %%
plt.figure(dpi=100)

ravals = []
for i in gcs['RADEG']:
    ravals += [(i+180)%360-180]

plt.scatter(ravals,gcs['DECDEG'],s=50,c='#fc00fc',marker='2',linewidths=0.6)
plt.plot(10.7,41.3,'b*')
plt.plot(23.46,30.65,'g*')
plt.xlabel('RA (deg)')
plt.ylabel('Dec (deg)')
#plt.ylim([28,55])
#plt.xlim([-6,26])
plt.gca().invert_xaxis()
plt.savefig('gc_positions.png', transparent=True)

# %%
ravals = []
for i in master_cat['RADEG']:
    ravals += [(i+180)%360-180]

plt.scatter(ravals,master_cat['DECDEG'],s=1)
plt.plot(10.7,41.3,'r*')
plt.plot(23.46,30.65,'g*')
plt.xlabel('RA (deg)')
plt.ylabel('Dec (deg)')
#plt.ylim([28,55])
#plt.xlim([-6,26])
plt.gca().invert_xaxis()
